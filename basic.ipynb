# %%
print("Hello World!")
# Out:
# Hello World!

# %%
2+2
# Out:
# 4

# %%
2>3
# Out:
# False

# %%
2>
# Out:
#   Cell In[4], line 1
#     2>
#       ^
# SyntaxError: invalid syntax

# %%
2>1
# Out:
# True

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("*"*10)
# Out:
# **********

# %%
print "Hello Wordl"
# Out:
#   Cell In[8], line 1
#     print "Hello Wordl"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
2+3
# Out:
# 5

# %%
x=10
y=2
unit_price=100
total_price=x*y*unit_price
print(total_price)
# Out:
# 2000
